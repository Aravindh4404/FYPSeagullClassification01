# %% [markdown]
# <a href="https://colab.research.google.com/github/Aravindh4404/FYPSeagullClassification01/blob/main/remove_duplicate_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install imagehash
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
import os
import imagehash
from PIL import Image
import shutil

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define paths to train and test folders in Google Drive
train_folder = '/content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull'
test_folder = '/content/drive/My Drive/FYP/Dataset/HQ2/test/Glaucous_Winged_Gull'
duplicates_folder = '/content/drive/My Drive/FYP/Dataset/HQ2/duplicates'  # New folder for duplicates

# Create duplicates folder if it doesn't exist
if not os.path.exists(duplicates_folder):
    os.makedirs(duplicates_folder)

# Function to calculate hash for each image in the folder
def get_image_hashes(folder_path):
    """Calculate hash for each image in the folder and return a dictionary with file paths."""
    image_hashes = {}
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            # Open and convert image to RGB
            image = Image.open(file_path).convert("RGB")
            # Get perceptual hash
            hash_value = imagehash.average_hash(image)
            image_hashes[file_path] = hash_value
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    return image_hashes

# Function to find and move duplicate images to a specified folder
def move_duplicates(train_folder, test_folder, duplicates_folder):
    train_hashes = get_image_hashes(train_folder)
    test_hashes = get_image_hashes(test_folder)

    all_hashes = {**train_hashes, **test_hashes}  # Combine train and test hashes

    # A dictionary to track images that have already been processed (i.e., duplicates)
    seen_hashes = {}
    duplicates = []

    # Check duplicates in train folder
    for file_path, hash_value in train_hashes.items():
        if hash_value in seen_hashes:
            duplicates.append(file_path)  # Add to duplicates
            try:
                # Move duplicate image to the duplicates folder
                shutil.copy(file_path, duplicates_folder)  # Copy to duplicates folder
                print(f"Moved duplicate image from train folder: {file_path}")
            except Exception as e:
                print(f"Error moving {file_path} from train folder: {e}")
        else:
            seen_hashes[hash_value] = file_path  # Track the hash

    # Check duplicates in test folder
    for file_path, hash_value in test_hashes.items():
        if hash_value in seen_hashes:
            duplicates.append(file_path)  # Add to duplicates
            try:
                # Move duplicate image to the duplicates folder
                shutil.copy(file_path, duplicates_folder)  # Copy to duplicates folder
                print(f"Moved duplicate image from test folder: {file_path}")
            except Exception as e:
                print(f"Error moving {file_path} from test folder: {e}")
        else:
            seen_hashes[hash_value] = file_path  # Track the hash

    return duplicates

# Step 3: Find and move duplicates
duplicates = move_duplicates(train_folder, test_folder, duplicates_folder)
if duplicates:
    print(f"Moved {len(duplicates)} duplicates to the duplicates folder.")
else:
    print("No duplicates found.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213904.525.jpg
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213903.914.jpg
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213901.174.jpg
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/900 (52).jpg
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213858.544.jpg
# Moved duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213904.551.jpg
# ...

# %%
from google.colab import drive
import os
import imagehash
from PIL import Image

# Step 1: Mount Google Drive
drive.mount('/content/drive')

# Step 2: Define paths to train and test folders in Google Drive
train_folder = '/content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull'
test_folder = '/content/drive/My Drive/FYP/Dataset/HQ2/test/Glaucous_Winged_Gull'

# Function to calculate hash for each image in the folder
def get_image_hashes(folder_path):
    """Calculate hash for each image in the folder and return a dictionary with file paths."""
    image_hashes = {}
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            # Open and convert image to RGB
            image = Image.open(file_path).convert("RGB")
            # Get perceptual hash
            hash_value = imagehash.average_hash(image)
            image_hashes[file_path] = hash_value
        except Exception as e:
            print(f"Error processing {file_path}: {e}")
    return image_hashes

# Function to find and delete duplicate images (both within the same folder and across train/test folders)
def delete_duplicates(train_folder, test_folder):
    train_hashes = get_image_hashes(train_folder)
    test_hashes = get_image_hashes(test_folder)

    all_hashes = {**train_hashes, **test_hashes}  # Combine train and test hashes

    # A dictionary to track images that have already been processed (i.e., duplicates)
    seen_hashes = {}
    duplicates = []

    # Check duplicates in train folder
    for file_path, hash_value in train_hashes.items():
        if hash_value in seen_hashes:
            duplicates.append(file_path)  # Add to duplicates
            try:
                os.remove(file_path)  # Delete duplicate image
                print(f"Deleted duplicate image from train folder: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path} from train folder: {e}")
        else:
            seen_hashes[hash_value] = file_path  # Track the hash

    # Check duplicates in test folder
    for file_path, hash_value in test_hashes.items():
        if hash_value in seen_hashes:
            duplicates.append(file_path)  # Add to duplicates
            try:
                os.remove(file_path)  # Delete duplicate image
                print(f"Deleted duplicate image from test folder: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path} from test folder: {e}")
        else:
            seen_hashes[hash_value] = file_path  # Track the hash

    return duplicates

# Step 3: Find and delete duplicates
duplicates = delete_duplicates(train_folder, test_folder)
if duplicates:
    print(f"Duplicates deleted: {len(duplicates)}")
else:
    print("No duplicates found.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213904.525.jpg
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213903.914.jpg
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213901.174.jpg
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/900 (52).jpg
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213858.544.jpg
# Deleted duplicate image from train folder: /content/drive/My Drive/FYP/Dataset/HQ2/train/Glaucous_Winged_Gull/1200 - 2024-10-22T213904.551.jpg
# ...
